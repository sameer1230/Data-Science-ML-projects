# %% [markdown]
# # Machine Learning - CEP

# %% [markdown]
# ### Standard Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Reading Dataset

# %%
df = pd.read_csv('weather.csv')
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# 1             9.355556                  7.227778      0.86            14.2646
# 2             9.377778                  9.377778      0.89             3.9284
# 3             8.288889                  5.944444      0.83            14.1036
# 4             8.755556                  6.977778      0.83            11.0446
# ...                ...                       ...       ...                ...
# 96448        26.016667                 26.016667      0.43            10.9963
# 96449        24.583333                 24.583333      0.48            10.0947
# 96450        22.038889                 22.038889      0.56             8.9838
# 96451        21.522222                 21.522222      0.60            10.5294
# 96452        20.438889                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 0                       251.0          15.8263         0.0
# 1                       259.0          15.8263         0.0
# 2                       204.0          14.9569         0.0
# 3                       269.0          15.8263         0.0
# 4                       259.0          15.8263         0.0
# ...                       ...              ...         ...
# 96448                    31.0          16.1000         0.0
# 96449                    20.0          15.5526         0.0
# 96450                    30.0          16.1000         0.0
# 96451                    20.0          16.1000         0.0
# 96452                    39.0          15.5204         0.0
#
#        Pressure (millibars)                           Daily Summary
# 0                   1015.13       Partly cloudy throughout the day.
# 1                   1015.63       Partly cloudy throughout the day.
# 2                   1015.94       Partly cloudy throughout the day.
# 3                   1016.41       Partly cloudy throughout the day.
# 4                   1016.51       Partly cloudy throughout the day.
# ...                     ...                                     ...
# 96448               1014.36  Partly cloudy starting in the morning.
# 96449               1015.16  Partly cloudy starting in the morning.
# 96450               1015.66  Partly cloudy starting in the morning.
# 96451               1015.95  Partly cloudy starting in the morning.
# 96452               1016.16  Partly cloudy starting in the morning.
#
# [96453 rows x 12 columns]

# %% [markdown]
# ### Getting Insights from the Dataset

# %%
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# 25%             5.828200              116.000000         8.339800         0.0
# 50%             9.965900              180.000000        10.046400         0.0
# 75%            14.135800              290.000000        14.812000         0.0
# max            63.852600              359.000000        16.100000         0.0
#
#        Pressure (millibars)
# count          96453.000000
# mean            1003.235956
# std              116.969906
# min                0.000000
# 25%             1011.900000
# 50%             1016.450000
# 75%             1021.090000
# max             1046.380000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
df.shape
# Out:
# (96453, 12)

# %%
df.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %% [markdown]
# #### Dropping null values

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %%
df.shape
# Out:
# (95936, 12)

# %%
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %% [markdown]
# ## Data Visualization

# %%
plt.figure(figsize=(10, 8))
sns.barplot(x = 'Precip Type', y = 'Temperature (C)', data = df, palette='inferno')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.barplot(x = 'Precip Type', y = 'Apparent Temperature (C)', data = df, palette='inferno')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.barplot(x = 'Precip Type', y = 'Humidity', data = df, palette='inferno')
plt.show()

# %%
import warnings

from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
df.tail()
# Out:
#                       Formatted Date        Summary Precip Type  \
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 96448        26.016667                 26.016667      0.43            10.9963
# 96449        24.583333                 24.583333      0.48            10.0947
# 96450        22.038889                 22.038889      0.56             8.9838
# 96451        21.522222                 21.522222      0.60            10.5294
# 96452        20.438889                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 96448                    31.0          16.1000         0.0
# 96449                    20.0          15.5526         0.0
# 96450                    30.0          16.1000         0.0
# 96451                    20.0          16.1000         0.0
# 96452                    39.0          15.5204         0.0
#
#        Pressure (millibars)                           Daily Summary
# 96448               1014.36  Partly cloudy starting in the morning.
# 96449               1015.16  Partly cloudy starting in the morning.
# 96450               1015.66  Partly cloudy starting in the morning.
# 96451               1015.95  Partly cloudy starting in the morning.
# 96452               1016.16  Partly cloudy starting in the morning.

# %%
pd.options.mode.chained_assignment = None

# %% [markdown]
# ### Extracting Year from the column 'Formatted Date'

# %%
df['Formatted Date'] = pd.to_datetime(df['Formatted Date'], utc=True)

# %%
df['Year'] = df['Formatted Date'].dt.year

# %%
df.head()
# Out:
#              Formatted Date        Summary Precip Type  Temperature (C)  \
# 0 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary  Year
# 0  Partly cloudy throughout the day.  2006
# 1  Partly cloudy throughout the day.  2006
# 2  Partly cloudy throughout the day.  2006
# 3  Partly cloudy throughout the day.  2006
# 4  Partly cloudy throughout the day.  2006

# %% [markdown]
# ### Checking for any redundant value in column 'Year'

# %%
df['Year'].value_counts()
# Out:
# 2010    8784
# 2008    8784
# 2006    8760
# 2007    8760
# 2009    8760
# 2011    8760
# 2013    8760
# 2015    8760
# 2014    8757
# 2012    8641
# 2016    8409
# 2005       1
# Name: Year, dtype: int64

# %%
df[df.Year==2005]
# Out:
#                 Formatted Date        Summary Precip Type  Temperature (C)  \
# 2880 2005-12-31 23:00:00+00:00  Partly Cloudy        rain         0.577778
#
#       Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 2880                     -4.05      0.89            17.1143
#
#       Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 2880                   140.0            9.982         0.0
#
#       Pressure (millibars)                      Daily Summary  Year
# 2880               1016.66  Mostly cloudy throughout the day.  2005

# %% [markdown]
# ### Removing the row where Year is equal to 2005 b/c it is the only one entry in the entire dataset which seems out of place and redundant

# %%
df = df.loc[df['Year'] != 2005]
df[df.Year==2005]
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Summary, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary, Year]
# Index: []

# %%
temp = df.groupby(['Year'], as_index=False)['Temperature (C)'].mean().sort_values(by='Temperature (C)')
temp
# Out:
#     Year  Temperature (C)
# 4   2010        11.200176
# 0   2006        11.215225
# 5   2011        11.524934
# 7   2013        11.941017
# 6   2012        11.949909
# 10  2016        12.123330
# 1   2007        12.134677
# 2   2008        12.161819
# 3   2009        12.269682
# 9   2015        12.312088
# 8   2014        12.528228

# %% [markdown]
# ## Continued Data Visualization

# %%
plt.figure(figsize=(10, 8))
sns.barplot(x='Year',y='Temperature (C)',data=temp, palette='magma')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.countplot(x='Year', hue='Precip Type', data=df, palette='magma')
plt.show()

# %%
pv_df = df.pivot_table('Temperature (C)',
                                index='Year',
                                columns='Precip Type', aggfunc='mean')
pv_df
# Out:
# Precip Type       rain      snow
# Year
# 2006         13.708034 -3.193675
# 2007         13.537126 -2.953423
# 2008         13.702243 -3.232784
# 2009         14.390530 -3.859594
# 2010         13.854148 -3.674035
# 2011         14.260676 -2.881744
# 2012         14.958689 -5.055838
# 2013         13.775156 -1.900027
# 2014         13.465303 -3.454227
# 2015         13.434018 -2.215826
# 2016         13.432758 -2.456109

# %%
pv_df.plot(kind='barh',figsize=(10,12),cmap='seismic')
plt.xlabel("Temperature")
plt.show()

# %%
plt.figure(figsize=(20, 20))
df.groupby('Summary')['Temperature (C)'].mean().plot(kind='barh',cmap='seismic')
plt.show()

# %%
plt.figure(figsize=(18, 20))
df.groupby('Summary')['Humidity'].mean().plot(kind='barh',cmap='seismic')
plt.show()

# %%
plt.figure(figsize=(12, 10))
sns.scatterplot(data=df, x='Temperature (C)', y='Humidity', hue='Precip Type', palette='magma')
plt.show()

# %%
sns.catplot(x='Year', y='Temperature (C)', hue='Precip Type', data=df, kind='point', palette='viridis')

# %% [markdown]
# ## Data PreProcessing

# %%
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     95935.000000              95935.000000  95935.000000
# mean         11.941094                 10.862687      0.734839
# std           9.570650                 10.717759      0.195724
# min         -21.822222                -27.716667      0.000000
# 25%           4.605556                  2.277778      0.600000
# 50%          12.033333                 12.033333      0.780000
# 75%          18.844444                 18.844444      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       95935.000000            95935.000000     95935.000000     95935.0
# mean           10.804870              187.519268        10.362406         0.0
# std             6.920734              107.385801         4.173801         0.0
# min             0.000000                0.000000         0.000000         0.0
# 25%             5.796000              116.000000         8.372000         0.0
# 50%             9.933700              180.000000        10.046400         0.0
# 75%            14.135800              290.000000        14.812000         0.0
# max            63.852600              359.000000        16.100000         0.0
#
#        Pressure (millibars)          Year
# count          95935.000000  95935.000000
# mean            1003.149897   2010.979371
# std              117.277579      3.154915
# min                0.000000   2006.000000
# 25%             1011.890000   2008.000000
# 50%             1016.420000   2011.000000
# 75%             1021.050000   2014.000000
# max             1046.380000   2016.000000

# %%
df[df['Pressure (millibars)'] == 0]
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 858   2006-08-14 16:00:00+00:00  Partly Cloudy        rain        22.477778
# 874   2006-08-15 08:00:00+00:00  Partly Cloudy        rain        21.061111
# 924   2006-08-17 10:00:00+00:00          Clear        rain        28.838889
# 945   2006-08-18 07:00:00+00:00          Clear        rain        24.950000
# 1074  2006-08-22 16:00:00+00:00  Partly Cloudy        rain        23.811111
# ...                         ...            ...         ...              ...
# 93147 2016-03-23 05:00:00+00:00          Clear        rain         2.750000
# 93149 2016-03-23 07:00:00+00:00          Clear        rain         3.838889
# 93150 2016-03-23 08:00:00+00:00          Clear        rain         5.000000
# 93152 2016-03-23 10:00:00+00:00          Clear        rain         5.050000
# 93153 2016-03-23 11:00:00+00:00          Clear        rain         5.100000
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 858                   22.477778      0.58            10.8192
# 874                   21.061111      0.73             7.7924
# 924                   29.611111      0.51             9.6600
# 945                   24.950000      0.69            16.0195
# 1074                  23.811111      0.45            16.0195
# ...                         ...       ...                ...
# 93147                 -0.322222      0.82            11.3988
# 93149                  1.716667      0.82             8.2593
# 93150                  4.005556      0.92             5.2486
# 93152                  2.472222      0.92            11.2700
# 93153                  1.800000      0.92            15.6009
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 858                     159.0          11.1251         0.0
# 874                     264.0          11.2056         0.0
# 924                     177.0           9.9820         0.0
# 945                     180.0           9.9015         0.0
# 1074                    290.0          11.2056         0.0
# ...                       ...              ...         ...
# 93147                    39.0           6.1180         0.0
# 93149                    58.0           6.1180         0.0
# 93150                    84.0           4.9910         0.0
# 93152                    10.0           4.9910         0.0
# 93153                    51.0           7.2128         0.0
#
#        Pressure (millibars)  \
# 858                     0.0
# 874                     0.0
# 924                     0.0
# 945                     0.0
# 1074                    0.0
# ...                     ...
# 93147                   0.0
# 93149                   0.0
# 93150                   0.0
# 93152                   0.0
# 93153                   0.0
#
#                                            Daily Summary  Year
# 858                           Mostly cloudy until night.  2006
# 874                         Partly cloudy until evening.  2006
# 924                         Partly cloudy until morning.  2006
# 945    Partly cloudy starting overnight continuing un...  2006
# 1074              Partly cloudy starting in the morning.  2006
# ...                                                  ...   ...
# 93147                Overcast starting in the afternoon.  2016
# 93149                Overcast starting in the afternoon.  2016
# 93150                Overcast starting in the afternoon.  2016
# 93152                Overcast starting in the afternoon.  2016
# 93153                Overcast starting in the afternoon.  2016
#
# [1288 rows x 13 columns]

# %% [markdown]
# ### 0 millibars Pressure on earth is not possible, so all the entries with 0 millibars Pressure does not make sense, so removing them.

# %%
df = df.loc[df['Pressure (millibars)'] != 0]
df[df['Pressure (millibars)'] == 0]
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Summary, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary, Year]
# Index: []

# %%
from scipy.stats import norm
import numpy as np
plt.hist(df.Humidity, bins=20, rwidth=0.8, density=True)
plt.xlabel('Humidity')
plt.ylabel('Count')

rng = np.arange(df.Humidity.min(), df.Humidity.max(), 0.1)
plt.plot(rng, norm.pdf(rng,df.Humidity.mean(),df.Humidity.std()))

# %% [markdown]
# ### Removing Outliers by Percentile method

# %%
min_thresold, max_thresold = df['Humidity'].quantile([0.001, 0.999])
min_thresold, max_thresold
# Out:
# (0.19, 1.0)

# %%
df[df['Humidity'] < min_thresold]
# Out:
#                  Formatted Date                   Summary Precip Type  \
# 9157  2007-04-23 11:00:00+00:00     Dry and Partly Cloudy        rain
# 9160  2007-04-23 14:00:00+00:00     Dry and Partly Cloudy        rain
# 9161  2007-04-23 15:00:00+00:00     Dry and Partly Cloudy        rain
# 9162  2007-04-23 16:00:00+00:00     Dry and Partly Cloudy        rain
# 12614 2007-07-17 12:00:00+00:00                     Clear        rain
# ...                         ...                       ...         ...
# 62802 2013-08-07 16:00:00+00:00     Dry and Partly Cloudy        rain
# 68411 2013-11-26 11:00:00+00:00  Breezy and Mostly Cloudy        rain
# 68422 2013-11-26 22:00:00+00:00       Breezy and Overcast        rain
# 75300 2014-03-11 14:00:00+00:00                     Clear        rain
# 79693 2015-08-11 14:00:00+00:00             Mostly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 9157         20.072222                 20.072222      0.17             2.8014
# 9160         21.205556                 21.205556      0.15             5.2969
# 9161         21.244444                 21.244444      0.15             2.5921
# 9162         20.161111                 20.161111      0.18             3.6708
# 12614        36.972222                 34.855556      0.17            19.4327
# ...                ...                       ...       ...                ...
# 62802        36.083333                 34.033333      0.18             5.2164
# 68411         2.733333                 -2.950000      0.15            30.6705
# 68422         1.133333                 -5.383333      0.15            34.2930
# 75300        15.022222                 15.022222      0.18            17.2753
# 79693        34.927778                 32.794444      0.18             2.6887
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 9157                    310.0           9.9820         0.0
# 9160                    128.0           9.9820         0.0
# 9161                    198.0          10.3523         0.0
# 9162                    172.0           9.9820         0.0
# 12614                   207.0          10.3523         0.0
# ...                       ...              ...         ...
# 62802                   121.0          16.1000         0.0
# 68411                     0.0          10.2557         0.0
# 68422                    20.0          16.1000         0.0
# 75300                    29.0          16.1000         0.0
# 79693                   301.0          16.1000         0.0
#
#        Pressure (millibars)  \
# 9157                1025.13
# 9160                1022.73
# 9161                1022.38
# 9162                1021.70
# 12614               1015.87
# ...                     ...
# 62802               1013.20
# 68411               1019.73
# 68422               1021.51
# 75300               1024.41
# 79693               1012.21
#
#                                            Daily Summary  Year
# 9157   Partly cloudy starting in the morning continui...  2007
# 9160   Partly cloudy starting in the morning continui...  2007
# 9161   Partly cloudy starting in the morning continui...  2007
# 9162   Partly cloudy starting in the morning continui...  2007
# 12614                          Clear throughout the day.  2007
# ...                                                  ...   ...
# 62802  Partly cloudy starting in the afternoon contin...  2013
# 68411  Mostly cloudy throughout the day and breezy ov...  2013
# 68422  Mostly cloudy throughout the day and breezy ov...  2013
# 75300                     Partly cloudy until afternoon.  2014
# 79693                  Partly cloudy throughout the day.  2015
#
# [87 rows x 13 columns]

# %%
df = df.loc[df['Humidity'] != 0.19]

# %%
df[df['Visibility (km)'] == 0]
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 1640  2006-12-16 07:00:00+00:00          Foggy        snow        -2.244444
# 1641  2006-12-16 08:00:00+00:00          Foggy        snow        -2.244444
# 1661  2006-12-17 04:00:00+00:00          Foggy        snow        -2.200000
# 1662  2006-12-17 05:00:00+00:00          Foggy        snow        -2.150000
# 1664  2006-12-17 07:00:00+00:00          Foggy        snow        -2.150000
# ...                         ...            ...         ...              ...
# 95499 2016-10-29 05:00:00+00:00  Mostly Cloudy        rain         6.550000
# 95500 2016-10-29 06:00:00+00:00  Mostly Cloudy        rain         6.988889
# 95501 2016-10-29 07:00:00+00:00  Mostly Cloudy        rain         8.200000
# 95502 2016-10-29 08:00:00+00:00  Mostly Cloudy        rain         9.894444
# 96247 2016-09-29 08:00:00+00:00          Clear        rain        19.861111
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 1640                  -2.244444      1.00             0.0000
# 1641                  -2.244444      1.00             3.2200
# 1661                  -2.200000      1.00             3.1717
# 1662                  -2.150000      1.00             3.2200
# 1664                  -5.177778      1.00             7.8085
# ...                         ...       ...                ...
# 95499                  3.816667      0.94            14.0231
# 95500                  4.327778      0.92            14.2163
# 95501                  5.683333      0.87            15.1984
# 95502                  7.577778      0.80            16.9050
# 96247                 19.861111      0.54            10.8031
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 1640                      0.0              0.0         0.0
# 1641                    170.0              0.0         0.0
# 1661                    158.0              0.0         0.0
# 1662                     90.0              0.0         0.0
# 1664                     19.0              0.0         0.0
# ...                       ...              ...         ...
# 95499                   280.0              0.0         0.0
# 95500                   281.0              0.0         0.0
# 95501                   287.0              0.0         0.0
# 95502                   294.0              0.0         0.0
# 96247                   240.0              0.0         0.0
#
#        Pressure (millibars)                 Daily Summary  Year
# 1640                1032.61     Foggy throughout the day.  2006
# 1641                1032.23     Foggy throughout the day.  2006
# 1661                1028.01     Foggy throughout the day.  2006
# 1662                1027.72     Foggy throughout the day.  2006
# 1664                1028.11     Foggy throughout the day.  2006
# ...                     ...                           ...   ...
# 95499               1028.27  Mostly cloudy until evening.  2016
# 95500               1028.22  Mostly cloudy until evening.  2016
# 95501               1028.17  Mostly cloudy until evening.  2016
# 95502               1028.11  Mostly cloudy until evening.  2016
# 96247               1026.20    Partly cloudy until night.  2016
#
# [162 rows x 13 columns]

# %%
min_thresold, max_thresold = df['Visibility (km)'].quantile([0.001, 0.999])
min_thresold, max_thresold
# Out:
# (0.0, 16.1)

# %%
df[df['Visibility (km)'] < min_thresold]
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Summary, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary, Year]
# Index: []

# %%
df = df.loc[df['Visibility (km)'] != 0.1449]

# %%
# sns.pairplot(df, vars=['Humidity', 'Temperature (C)'], hue='Summary')

# %%
df2 = df.copy()
df2.head()
# Out:
#              Formatted Date        Summary Precip Type  Temperature (C)  \
# 0 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary  Year
# 0  Partly cloudy throughout the day.  2006
# 1  Partly cloudy throughout the day.  2006
# 2  Partly cloudy throughout the day.  2006
# 3  Partly cloudy throughout the day.  2006
# 4  Partly cloudy throughout the day.  2006

# %% [markdown]
# ### All entries of Column 'Loud Cover' are 0, will drop it eventually for the working dataset.

# %%
df2['Loud Cover'].unique()
# Out:
# array([0.])

# %% [markdown]
# ##### Formatted Date, Daily Summary, Apparent Temperature, Loud Cover are useless columns and won't make any difference on our model, Precip Type and Year have negligible effect on the model, and Wind bearing is actually the direction of the wind, Hence all these columns are dropped.

# %%
df2 = df2.drop(['Formatted Date', 'Daily Summary','Precip Type', 'Apparent Temperature (C)', 'Loud Cover', 'Year',
               'Wind Bearing (degrees)'],axis=1)

# %%
df2.head()
# Out:
#          Summary  Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0  Partly Cloudy         9.472222      0.89            14.1197
# 1  Partly Cloudy         9.355556      0.86            14.2646
# 2  Mostly Cloudy         9.377778      0.89             3.9284
# 3  Partly Cloudy         8.288889      0.83            14.1036
# 4  Mostly Cloudy         8.755556      0.83            11.0446
#
#    Visibility (km)  Pressure (millibars)
# 0          15.8263               1015.13
# 1          15.8263               1015.63
# 2          14.9569               1015.94
# 3          15.8263               1016.41
# 4          15.8263               1016.51

# %%
df['Summary'].unique()
# Out:
# array(['Partly Cloudy', 'Mostly Cloudy', 'Overcast', 'Foggy',
#        'Breezy and Mostly Cloudy', 'Clear', 'Breezy and Partly Cloudy',
#        'Breezy and Overcast', 'Humid and Mostly Cloudy',
#        'Humid and Partly Cloudy', 'Windy and Foggy', 'Windy and Overcast',
#        'Breezy and Foggy', 'Windy and Partly Cloudy', 'Breezy',
#        'Dry and Partly Cloudy', 'Windy and Mostly Cloudy',
#        'Dangerously Windy and Partly Cloudy', 'Dry', 'Windy',
#        'Humid and Overcast', 'Light Rain', 'Drizzle', 'Windy and Dry',
#        'Dry and Mostly Cloudy', 'Breezy and Dry', 'Rain'], dtype=object)

# %%
df['Summary'].value_counts()
# Out:
# Partly Cloudy                          31491
# Mostly Cloudy                          27778
# Overcast                               16361
# Clear                                  10033
# Foggy                                   6984
# Breezy and Overcast                      525
# Breezy and Mostly Cloudy                 511
# Breezy and Partly Cloudy                 379
# Dry and Partly Cloudy                     79
# Light Rain                                63
# Windy and Partly Cloudy                   63
# Windy and Overcast                        44
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   34
# Dry                                       31
# Breezy                                    30
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# Humid and Overcast                         7
# Windy and Foggy                            4
# Dangerously Windy and Partly Cloudy        1
# Windy                                      1
# Windy and Dry                              1
# Breezy and Dry                             1
# Name: Summary, dtype: int64

# %%
entries_to_remove = ['Breezy and Overcast', 'Breezy and Mostly Cloudy', 'Breezy and Partly Cloudy',
                     'Dry and Partly Cloudy', 'Light Rain', 'Windy and Partly Cloudy', 'Windy and Overcast',
                     'Humid and Mostly Cloudy', 'Drizzle', 'Windy and Mostly Cloudy', 'Humid and Partly Cloudy',
                     'Dry and Mostly Cloudy', 'Rain', 'Humid and Overcast', 'Dangerously Windy and Partly Cloudy',
                     'Windy','Mostly Cloudy']

df2 = df2.loc[~df['Summary'].isin(entries_to_remove)].dropna()

# %%
df2['Summary'].value_counts()
# Out:
# Partly Cloudy       31491
# Overcast            16361
# Clear               10033
# Foggy                6984
# Breezy and Foggy       35
# Dry                    31
# Breezy                 30
# Windy and Foggy         4
# Windy and Dry           1
# Breezy and Dry          1
# Name: Summary, dtype: int64

# %%
df3 = df2.copy()

# %% [markdown]
# ### Scaling down 'Summary' entries to 3 classes.

# %%
mapping = {
    'Cloudy': ['Partly Cloudy','Overcast'],
    'Clear': ['Clear','Dry','Breezy and Dry','Windy and Dry','Breezy'],
    'Foggy': ['Foggy', 'Windy and Foggy', 'Breezy and Foggy'],
}

# %%
df3['Summary'] = df2['Summary'].map({entry: category for category, entries in mapping.items() for entry in entries})
df3
# Out:
#       Summary  Temperature (C)  Humidity  Wind Speed (km/h)  Visibility (km)  \
# 0      Cloudy         9.472222      0.89            14.1197          15.8263
# 1      Cloudy         9.355556      0.86            14.2646          15.8263
# 3      Cloudy         8.288889      0.83            14.1036          15.8263
# 5      Cloudy         9.222222      0.85            13.9587          14.9569
# 6      Cloudy         7.733333      0.95            12.3648           9.9820
# ...       ...              ...       ...                ...              ...
# 96448  Cloudy        26.016667      0.43            10.9963          16.1000
# 96449  Cloudy        24.583333      0.48            10.0947          15.5526
# 96450  Cloudy        22.038889      0.56             8.9838          16.1000
# 96451  Cloudy        21.522222      0.60            10.5294          16.1000
# 96452  Cloudy        20.438889      0.61             5.8765          15.5204
#
#        Pressure (millibars)
# 0                   1015.13
# 1                   1015.63
# 3                   1016.41
# 5                   1016.66
# 6                   1016.72
# ...                     ...
# 96448               1014.36
# 96449               1015.16
# 96450               1015.66
# 96451               1015.95
# 96452               1016.16
#
# [64971 rows x 6 columns]

# %%
df3['Summary'].unique()
# Out:
# array(['Cloudy', 'Foggy', 'Clear'], dtype=object)

# %%
df3['Summary'].value_counts()
# Out:
# Cloudy    47852
# Clear     10096
# Foggy      7023
# Name: Summary, dtype: int64

# %%
df3 = df3.dropna()

# %%
df3['Summary'].unique()
# Out:
# array(['Cloudy', 'Foggy', 'Clear'], dtype=object)

# %%
df3.groupby('Summary')['Temperature (C)'].mean().plot(kind='barh',cmap='seismic')
# Out:
# <AxesSubplot:ylabel='Summary'>

# %%
df3.head()
# Out:
#   Summary  Temperature (C)  Humidity  Wind Speed (km/h)  Visibility (km)  \
# 0  Cloudy         9.472222      0.89            14.1197          15.8263
# 1  Cloudy         9.355556      0.86            14.2646          15.8263
# 3  Cloudy         8.288889      0.83            14.1036          15.8263
# 5  Cloudy         9.222222      0.85            13.9587          14.9569
# 6  Cloudy         7.733333      0.95            12.3648           9.9820
#
#    Pressure (millibars)
# 0               1015.13
# 1               1015.63
# 3               1016.41
# 5               1016.66
# 6               1016.72

# %% [markdown]
# ### Assigning X (predictor) and Y (target) variable

# %%
X = df2.drop(['Summary'],axis=1)
X.head()
# Out:
#    Temperature (C)  Humidity  Wind Speed (km/h)  Visibility (km)  \
# 0         9.472222      0.89            14.1197          15.8263
# 1         9.355556      0.86            14.2646          15.8263
# 3         8.288889      0.83            14.1036          15.8263
# 5         9.222222      0.85            13.9587          14.9569
# 6         7.733333      0.95            12.3648           9.9820
#
#    Pressure (millibars)
# 0               1015.13
# 1               1015.63
# 3               1016.41
# 5               1016.66
# 6               1016.72

# %%
plt.figure(figsize=(10,7))
corr = X.corr()
sns.heatmap(corr, annot=True)
plt.show()

# %%
Y = df3.Summary
Y.head()
# Out:
# 0    Cloudy
# 1    Cloudy
# 3    Cloudy
# 5    Cloudy
# 6    Cloudy
# Name: Summary, dtype: object

# %% [markdown]
# ### Performing ZScore Standardization on X (predictor)

# %%
# from scipy import stats

# X = X.apply(stats.zscore)
# X.head()

# %% [markdown]
# # Training Machine Learning Models

# %%
from sklearn import metrics

# %% [markdown]
# ##### Splitting X,Y into train, test data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y)

# %% [markdown]
# ## Training K Nearest Neighbor

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 5)

# %%
knn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier()

# %%
Y_pred = knn.predict(X_test)

# %%
accuracy = metrics.accuracy_score(Y_test,Y_pred)*100
percent = f"{accuracy:.2f}"
print("The model is providing %s percent accurate result." %percent)
# Out:
# The model is providing 81.53 percent accurate result.

# %% [markdown]
# ##### Creating heatmap of Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(Y_test, Y_pred)
cm
# Out:
# array([[  596,  1878,    28],
#        [  877, 10986,    86],
#        [   10,   121,  1661]], dtype=int64)

# %%
plt.figure(figsize=(7,5))
sns.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Out:
# Text(42.0, 0.5, 'Actual')

# %% [markdown]
# ##### Creating Classifcation Report of KNN model #1

# %%
from sklearn.metrics import classification_report

print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        Clear       0.40      0.24      0.30      2502
#       Cloudy       0.85      0.92      0.88     11949
#        Foggy       0.94      0.93      0.93      1792
#
#     accuracy                           0.82     16243
#    macro avg       0.73      0.69      0.70     16243
# weighted avg       0.79      0.82      0.80     16243

# %% [markdown]
# ### Training 2nd KNN Model

# %%
knn_2 = KNeighborsClassifier(n_neighbors = 3, weights='distance')

# %%
knn_2.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3, weights='distance')

# %%
Y2_pred = knn_2.predict(X_test)

# %%
accuracy = metrics.accuracy_score(Y_test,Y2_pred)*100
percent = f"{accuracy:.2f}"
print("The model is providing %s percent accurate result." %percent)
# Out:
# The model is providing 80.40 percent accurate result.

# %% [markdown]
# ### Training 3rd KNN Model

# %%
knn_3 = KNeighborsClassifier(n_neighbors = 20)

# %%
knn_3.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
Y3_pred = knn_3.predict(X_test)

# %%
accuracy = metrics.accuracy_score(Y_test,Y3_pred)*100
percent = f"{accuracy:.2f}"
print("The model is providing %s percent accurate result." %percent)
# Out:
# The model is providing 83.17 percent accurate result.

# %% [markdown]
# ##### Creating Heatmap of Confusion Matrix

# %%
cm = confusion_matrix(Y_test, Y3_pred)

plt.figure(figsize=(7,5))
sns.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Out:
# Text(42.0, 0.5, 'Actual')

# %% [markdown]
# ##### Creating Classification Report of KNN model #3

# %%
print(classification_report(Y_test, Y3_pred))
# Out:
#               precision    recall  f1-score   support
#
#        Clear       0.49      0.16      0.24      2502
#       Cloudy       0.84      0.96      0.89     11949
#        Foggy       0.94      0.92      0.93      1792
#
#     accuracy                           0.83     16243
#    macro avg       0.76      0.68      0.69     16243
# weighted avg       0.80      0.83      0.80     16243

# %% [markdown]
# ## Training Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression

log_model = LogisticRegression()

log_model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
lg_predict = log_model.predict(X_test)

# %%
accuracy = metrics.accuracy_score(Y_test,lg_predict)*100
percent = f"{accuracy:.2f}"
print("The model is providing %s percent accurate result." %percent)
# Out:
# The model is providing 84.43 percent accurate result.

# %% [markdown]
# ##### Creating heatmap of Confusion Matrix

# %%
lg_cm = confusion_matrix(Y_test, lg_predict)

plt.figure(figsize=(7,5))
sns.heatmap(lg_cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Out:
# Text(42.0, 0.5, 'Actual')

# %% [markdown]
# ##### Creating Classifcation report of Logistic Model #1

# %%
print(classification_report(Y_test, lg_predict))
# Out:
#               precision    recall  f1-score   support
#
#        Clear       0.00      0.00      0.00      2502
#       Cloudy       0.83      1.00      0.90     11949
#        Foggy       0.98      0.99      0.99      1792
#
#     accuracy                           0.84     16243
#    macro avg       0.60      0.66      0.63     16243
# weighted avg       0.72      0.84      0.77     16243

# %% [markdown]
# ### Training 2nd Logistic Model

# %%
log_model_2 = LogisticRegression(penalty='elasticnet', C=0.5, solver='saga', l1_ratio=0.5)

log_model_2.fit(X_train,Y_train)
# Out:
# LogisticRegression(C=0.5, l1_ratio=0.5, penalty='elasticnet', solver='saga')

# %%
lg_2_predict = log_model_2.predict(X_test)

# %%
accuracy = metrics.accuracy_score(Y_test,lg_2_predict)*100
percent = f"{accuracy:.2f}"
print("The model is providing %s percent accurate result." %percent)
# Out:
# The model is providing 84.09 percent accurate result.

# %% [markdown]
# ##### Creating Classifcation report of Logistic Model #2

# %%
print(classification_report(Y_test, lg_2_predict))
# Out:
#               precision    recall  f1-score   support
#
#        Clear       0.00      0.00      0.00      2502
#       Cloudy       0.83      1.00      0.90     11949
#        Foggy       0.95      0.98      0.97      1792
#
#     accuracy                           0.84     16243
#    macro avg       0.59      0.66      0.62     16243
# weighted avg       0.71      0.84      0.77     16243

# %% [markdown]
# ### Training 3rd Logistic Model

# %%
log_model_3 = LogisticRegression(C=1.5)

log_model_3.fit(X_train,Y_train)
# Out:
# LogisticRegression(C=1.5)

# %%
lg_3_predict = log_model_3.predict(X_test)

# %%
accuracy = metrics.accuracy_score(Y_test,lg_3_predict)*100
percent = f"{accuracy:.2f}"
print("The model is providing %s percent accurate result." %percent)
# Out:
# The model is providing 84.46 percent accurate result.

# %% [markdown]
# ##### Creating Classifcation report of Logistic Model #3

# %%
print(classification_report(Y_test, lg_3_predict))
# Out:
#               precision    recall  f1-score   support
#
#        Clear       0.00      0.00      0.00      2502
#       Cloudy       0.83      1.00      0.91     11949
#        Foggy       0.98      1.00      0.99      1792
#
#     accuracy                           0.84     16243
#    macro avg       0.60      0.67      0.63     16243
# weighted avg       0.72      0.84      0.77     16243

# %%
feature_names = X.columns
feature_names
# Out:
# Index(['Temperature (C)', 'Humidity', 'Wind Speed (km/h)', 'Visibility (km)',
#        'Pressure (millibars)'],
#       dtype='object')

# %% [markdown]
# ### Plotting Feature Importance Graph on Logistic Regression Model #1

# %%
coefficients = log_model.coef_[0]
absolute_coefficients = abs(coefficients)

sorted_indices = absolute_coefficients.argsort()[::-1]
sorted_coefficients = absolute_coefficients[sorted_indices]
sorted_feature_names = feature_names[sorted_indices]

# %%
plt.figure(figsize=(10, 10))
plt.barh(range(len(sorted_feature_names)), sorted_coefficients)
plt.yticks(range(len(sorted_feature_names)), sorted_feature_names)
plt.xlabel('Features')
plt.ylabel('Absolute Coefficients')
plt.title('Feature Importance')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Performing K Fold Cross Validation

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

cross_val_score(LogisticRegression(), X_train, Y_train, cv=cv)
# Out:
# array([0.84721937, 0.83931869, 0.84547507, 0.83490663, 0.83983173])

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

cross_val_score(KNeighborsClassifier(), X_train, Y_train, cv=cv)
# Out:
# array([0.814488  , 0.81541145, 0.81561666, 0.81561666, 0.81182023])

# %%
df2.head()
# Out:
#          Summary  Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0  Partly Cloudy         9.472222      0.89            14.1197
# 1  Partly Cloudy         9.355556      0.86            14.2646
# 3  Partly Cloudy         8.288889      0.83            14.1036
# 5  Partly Cloudy         9.222222      0.85            13.9587
# 6  Partly Cloudy         7.733333      0.95            12.3648
#
#    Visibility (km)  Pressure (millibars)
# 0          15.8263               1015.13
# 1          15.8263               1015.63
# 3          15.8263               1016.41
# 5          14.9569               1016.66
# 6           9.9820               1016.72

# %%
df2.tail()
# Out:
#              Summary  Temperature (C)  Humidity  Wind Speed (km/h)  \
# 96448  Partly Cloudy        26.016667      0.43            10.9963
# 96449  Partly Cloudy        24.583333      0.48            10.0947
# 96450  Partly Cloudy        22.038889      0.56             8.9838
# 96451  Partly Cloudy        21.522222      0.60            10.5294
# 96452  Partly Cloudy        20.438889      0.61             5.8765
#
#        Visibility (km)  Pressure (millibars)
# 96448          16.1000               1014.36
# 96449          15.5526               1015.16
# 96450          16.1000               1015.66
# 96451          16.1000               1015.95
# 96452          15.5204               1016.16

# %%
X.columns
# Out:
# Index(['Temperature (C)', 'Humidity', 'Wind Speed (km/h)', 'Visibility (km)',
#        'Pressure (millibars)'],
#       dtype='object')

# %%
Y_train.value_counts()
# Out:
# Cloudy    35903
# Clear      7594
# Foggy      5231
# Name: Summary, dtype: int64

# %% [markdown]
# ## Predicting 'Summary'

# %%
def predict_summary(temperature,humidity,wind_speed,visbility,pressure):    
    
    x = np.zeros(len(X.columns))
    x[0] = temperature
    x[1] = humidity
    x[2] = wind_speed
    x[3] = visbility
    x[4] = pressure

    return knn_3.predict([x])[0]

# %%
predict_summary(26.016667, 0.43, 10.9963, 16.1000, 1014.36)
# Out:
# 'Cloudy'

# %%
predict_summary(-15, 1, 5, 40, 1012)
# Out:
# 'Clear'

# %%
knn_3.predict([[26.016667, 0.43, 10.9963, 16.1000, 1014.36]])
# Out:
# array(['Cloudy'], dtype=object)

# %%
knn_3.predict([[-15, 1, 5, 40, 1012]])
# Out:
# array(['Clear'], dtype=object)

# %%
knn_3.predict([[9.377778, 0.89, 3.9284, 14.9569, 1015.94]])
# Out:
# array(['Cloudy'], dtype=object)

# %%
knn_3.predict([[16.072222,0.88,2.7853,15.7297,1015.25]])
# Out:
# array(['Cloudy'], dtype=object)

# %%
knn_3.predict([[15.550000,0.63,11.1573,11.4471,1016.17]])
# Out:
# array(['Cloudy'], dtype=object)

# %%
predict_summary(9.377778, 0.89, 3.9284, 14.9569, 1015.94)
# Out:
# 'Cloudy'

# %%
predict_summary(22.038889, 0.56, 8.9838, 16.1000, 1015.66)
# Out:
# 'Cloudy'

# %%
predict_summary(-10, 0.9, 8, 1, 1018)
# Out:
# 'Foggy'

# %%
def lg_predict_summary(temperature,humidity,wind_speed,visbility,pressure):    
    
    x = np.zeros(len(X.columns))
    x[0] = temperature
    x[1] = humidity
    x[2] = wind_speed
    x[3] = visbility
    x[4] = pressure

    return log_model_3.predict([x])[0]

# %%
lg_predict_summary(9.5, 0.9, 14, 16, 1015)
# Out:
# 'Cloudy'

# %%
lg_predict_summary(-15, 1, 5, 40, 1012)
# Out:
# 'Clear'

# %%
lg_predict_summary(-10, 0.9, 8, 1, 1018)
# Out:
# 'Foggy'

# %%
lg_predict_summary(9.377778, 0.89, 3.9284, 14.9569, 1015.94)
# Out:
# 'Cloudy'

# %%
knn_3.predict([[9.5, 0.9, 14, 16, 1015]])
# Out:
# array(['Cloudy'], dtype=object)

# %%
log_model_3.predict([[9.5, 0.9, 14, 16, 1015]])
# Out:
# array(['Cloudy'], dtype=object)

# %%
log_model_3.predict([[-10, 0.5, 14, 10, 1015]])
# Out:
# array(['Cloudy'], dtype=object)

# %%
import ipywidgets as widgets
from IPython.display import display

# %%
temperature_slider = widgets.FloatSlider(value=0, min=-20, max=40, step=0.1, description='Temperature:')
humidity_slider = widgets.FloatSlider(value=0, min=0, max=1, step=0.1, description='Humidity:')
wind_speed_slider = widgets.FloatSlider(value=0, min=0, max=100, step=1, description='Wind Speed:')
visibility_slider = widgets.FloatSlider(value=0, min=0, max=20, step=0.1, description='Visibility:')
pressure_slider = widgets.FloatSlider(value=1000, min=1000, max=1050, step=1, description='Pressure:')

# %%
predict_button = widgets.Button(description='Predict Weather')

# %%
def lg_predict_summary(temperature,humidity,wind_speed,visbility,pressure):    
    
    x = np.zeros(len(X.columns))
    x[0] = temperature
    x[1] = humidity
    x[2] = wind_speed
    x[3] = visbility
    x[4] = pressure

    return log_model_3.predict([x])[0]

def predict_weather(button):
    # Retrieve the slider values
    temperature = temperature_slider.value
    humidity = humidity_slider.value
    wind_speed = wind_speed_slider.value
    visibility = visibility_slider.value
    pressure = pressure_slider.value

    # Call your machine learning model to make a prediction
    prediction = predict_summary(temperature, humidity, wind_speed, visibility, pressure)

    # Display the prediction result
    prediction_label.value = 'Prediction: ' + prediction

# %%
predict_button.on_click(predict_weather)
prediction_label = widgets.Label()

# %%
display(temperature_slider, humidity_slider, wind_speed_slider, visibility_slider, 
        pressure_slider, predict_button, prediction_label)
# Out:
# FloatSlider(value=-13.3, description='Temperature:', max=40.0, min=-20.0)
# FloatSlider(value=0.6, description='Humidity:', max=1.0)
# FloatSlider(value=6.0, description='Wind Speed:', step=1.0)
# FloatSlider(value=20.0, description='Visibility:', max=20.0)
# FloatSlider(value=1024.0, description='Pressure:', max=1050.0, min=1000.0, step=1.0)
# Button(description='Predict Weather', style=ButtonStyle())
# Label(value='')

# %% [markdown]
# # Artificial Neural Networks

# %%
from keras.models import Model
from keras.layers import Input, Dense
from keras.losses import CategoricalCrossentropy

Y_train_encoded = pd.get_dummies(Y_train)  
Y_train_numpy = Y_train_encoded.values

# %% [markdown]
# ## Model 1

# %%
input_layer = Input(shape=(5,))  
output_shape = Y_train_encoded.shape[1]     
output_layer = Dense(output_shape, activation='softmax')(input_layer)
modeld1 = Model(inputs=input_layer, outputs=output_layer)

modeld1.compile(loss=CategoricalCrossentropy(), optimizer='adam', metrics=['accuracy'])

# %%
history = modeld1.fit(x=X_train, y=Y_train_numpy, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
# 1523/1523 - 3s - loss: 29.1515 - accuracy: 0.6066 - 3s/epoch - 2ms/step
# Epoch 2/100
# 1523/1523 - 2s - loss: 0.5227 - accuracy: 0.8028 - 2s/epoch - 1ms/step
# Epoch 3/100
# 1523/1523 - 2s - loss: 0.4809 - accuracy: 0.8200 - 2s/epoch - 1ms/step
# Epoch 4/100
# 1523/1523 - 2s - loss: 0.4687 - accuracy: 0.8242 - 2s/epoch - 1ms/step
# Epoch 5/100
# 1523/1523 - 2s - loss: 0.4614 - accuracy: 0.8250 - 2s/epoch - 1ms/step
# Epoch 6/100
# 1523/1523 - 2s - loss: 0.4589 - accuracy: 0.8269 - 2s/epoch - 1ms/step
# Epoch 7/100
# 1523/1523 - 2s - loss: 0.4555 - accuracy: 0.8279 - 2s/epoch - 1ms/step
# Epoch 8/100
# 1523/1523 - 2s - loss: 0.4518 - accuracy: 0.8289 - 2s/epoch - 1ms/step
# Epoch 9/100
# 1523/1523 - 2s - loss: 0.4454 - accuracy: 0.8324 - 2s/epoch - 1ms/step
# Epoch 10/100
# 1523/1523 - 2s - loss: 0.4489 - accuracy: 0.8313 - 2s/epoch - 1ms/step
# Epoch 11/100
# 1523/1523 - 2s - loss: 0.4476 - accuracy: 0.8319 - 2s/epoch - 1ms/step
# Epoch 12/100
# 1523/1523 - 2s - loss: 0.4452 - accuracy: 0.8318 - 2s/epoch - 1ms/step
# Epoch 13/100
# 1523/1523 - 2s - loss: 0.4450 - accuracy: 0.8333 - 2s/epoch - 1ms/step
# Epoch 14/100
# 1523/1523 - 2s - loss: 0.4448 - accuracy: 0.8323 - 2s/epoch - 1ms/step
# Epoch 15/100
# 1523/1523 - 2s - loss: 0.4476 - accuracy: 0.8309 - 2s/epoch - 1ms/step
# Epoch 16/100
# 1523/1523 - 2s - loss: 0.4462 - accuracy: 0.8316 - 2s/epoch - 1ms/step
# Epoch 17/100
# 1523/1523 - 2s - loss: 0.4459 - accuracy: 0.8317 - 2s/epoch - 1ms/step
# Epoch 18/100
# 1523/1523 - 2s - loss: 0.4441 - accuracy: 0.8332 - 2s/epoch - 1ms/step
# Epoch 19/100
# 1523/1523 - 2s - loss: 0.4445 - accuracy: 0.8319 - 2s/epoch - 1ms/step
# Epoch 20/100
# 1523/1523 - 2s - loss: 0.4412 - accuracy: 0.8339 - 2s/epoch - 1ms/step
# Epoch 21/100
# 1523/1523 - 2s - loss: 0.4452 - accuracy: 0.8334 - 2s/epoch - 1ms/step
# Epoch 22/100
# 1523/1523 - 2s - loss: 0.4484 - accuracy: 0.8315 - 2s/epoch - 1ms/step
# Epoch 23/100
# 1523/1523 - 3s - loss: 0.4467 - accuracy: 0.8321 - 3s/epoch - 2ms/step
# Epoch 24/100
# 1523/1523 - 2s - loss: 0.4443 - accuracy: 0.8326 - 2s/epoch - 1ms/step
# Epoch 25/100
# 1523/1523 - 2s - loss: 0.4427 - accuracy: 0.8330 - 2s/epoch - 1ms/step
# Epoch 26/100
# 1523/1523 - 2s - loss: 0.4454 - accuracy: 0.8330 - 2s/epoch - 1ms/step
# Epoch 27/100
# 1523/1523 - 2s - loss: 0.4424 - accuracy: 0.8341 - 2s/epoch - 1ms/step
# Epoch 28/100
# 1523/1523 - 2s - loss: 0.4419 - accuracy: 0.8344 - 2s/epoch - 2ms/step
# Epoch 29/100
# 1523/1523 - 2s - loss: 0.4417 - accuracy: 0.8336 - 2s/epoch - 1ms/step
# Epoch 30/100
# 1523/1523 - 2s - loss: 0.4461 - accuracy: 0.8330 - 2s/epoch - 1ms/step
# Epoch 31/100
# 1523/1523 - 2s - loss: 0.4456 - accuracy: 0.8332 - 2s/epoch - 1ms/step
# Epoch 32/100
# 1523/1523 - 2s - loss: 0.4453 - accuracy: 0.8319 - 2s/epoch - 2ms/step
# Epoch 33/100
# 1523/1523 - 2s - loss: 0.4403 - accuracy: 0.8354 - 2s/epoch - 1ms/step
# Epoch 34/100
# 1523/1523 - 2s - loss: 0.4466 - accuracy: 0.8316 - 2s/epoch - 1ms/step
# Epoch 35/100
# 1523/1523 - 2s - loss: 0.4384 - accuracy: 0.8351 - 2s/epoch - 1ms/step
# Epoch 36/100
# 1523/1523 - 2s - loss: 0.4454 - accuracy: 0.8323 - 2s/epoch - 1ms/step
# Epoch 37/100
# 1523/1523 - 2s - loss: 0.4410 - accuracy: 0.8345 - 2s/epoch - 1ms/step
# Epoch 38/100
# 1523/1523 - 2s - loss: 0.4398 - accuracy: 0.8352 - 2s/epoch - 1ms/step
# Epoch 39/100
# 1523/1523 - 3s - loss: 0.4461 - accuracy: 0.8331 - 3s/epoch - 2ms/step
# Epoch 40/100
# 1523/1523 - 3s - loss: 0.4453 - accuracy: 0.8323 - 3s/epoch - 2ms/step
# Epoch 41/100
# 1523/1523 - 2s - loss: 0.4455 - accuracy: 0.8332 - 2s/epoch - 1ms/step
# Epoch 42/100
# 1523/1523 - 2s - loss: 0.4462 - accuracy: 0.8332 - 2s/epoch - 1ms/step
# Epoch 43/100
# 1523/1523 - 2s - loss: 0.4464 - accuracy: 0.8333 - 2s/epoch - 1ms/step
# Epoch 44/100
# 1523/1523 - 2s - loss: 0.4422 - accuracy: 0.8339 - 2s/epoch - 1ms/step
# Epoch 45/100
# 1523/1523 - 2s - loss: 0.4406 - accuracy: 0.8349 - 2s/epoch - 1ms/step
# Epoch 46/100
# 1523/1523 - 2s - loss: 0.4404 - accuracy: 0.8345 - 2s/epoch - 1ms/step
# Epoch 47/100
# 1523/1523 - 2s - loss: 0.4422 - accuracy: 0.8341 - 2s/epoch - 1ms/step
# Epoch 48/100
# 1523/1523 - 2s - loss: 0.4407 - accuracy: 0.8346 - 2s/epoch - 1ms/step
# Epoch 49/100
# 1523/1523 - 2s - loss: 0.4413 - accuracy: 0.8359 - 2s/epoch - 1ms/step
# Epoch 50/100
# 1523/1523 - 2s - loss: 0.4432 - accuracy: 0.8330 - 2s/epoch - 1ms/step
# Epoch 51/100
# 1523/1523 - 2s - loss: 0.4416 - accuracy: 0.8348 - 2s/epoch - 1ms/step
# Epoch 52/100
# 1523/1523 - 2s - loss: 0.4460 - accuracy: 0.8330 - 2s/epoch - 1ms/step
# Epoch 53/100
# 1523/1523 - 2s - loss: 0.4479 - accuracy: 0.8316 - 2s/epoch - 1ms/step
# Epoch 54/100
# 1523/1523 - 2s - loss: 0.4380 - accuracy: 0.8359 - 2s/epoch - 1ms/step
# Epoch 55/100
# 1523/1523 - 2s - loss: 0.4450 - accuracy: 0.8340 - 2s/epoch - 1ms/step
# Epoch 56/100
# 1523/1523 - 2s - loss: 0.4443 - accuracy: 0.8339 - 2s/epoch - 1ms/step
# Epoch 57/100
# 1523/1523 - 2s - loss: 0.4447 - accuracy: 0.8341 - 2s/epoch - 1ms/step
# Epoch 58/100
# 1523/1523 - 2s - loss: 0.4426 - accuracy: 0.8334 - 2s/epoch - 1ms/step
# Epoch 59/100
# 1523/1523 - 2s - loss: 0.4398 - accuracy: 0.8346 - 2s/epoch - 1ms/step
# Epoch 60/100
# 1523/1523 - 2s - loss: 0.4429 - accuracy: 0.8338 - 2s/epoch - 1ms/step
# Epoch 61/100
# 1523/1523 - 2s - loss: 0.4435 - accuracy: 0.8347 - 2s/epoch - 1ms/step
# Epoch 62/100
# 1523/1523 - 2s - loss: 0.4408 - accuracy: 0.8347 - 2s/epoch - 1ms/step
# Epoch 63/100
# 1523/1523 - 2s - loss: 0.4449 - accuracy: 0.8336 - 2s/epoch - 1ms/step
# Epoch 64/100
# 1523/1523 - 2s - loss: 0.4460 - accuracy: 0.8335 - 2s/epoch - 1ms/step
# Epoch 65/100
# 1523/1523 - 2s - loss: 0.4441 - accuracy: 0.8327 - 2s/epoch - 1ms/step
# Epoch 66/100
# 1523/1523 - 2s - loss: 0.4439 - accuracy: 0.8338 - 2s/epoch - 1ms/step
# Epoch 67/100
# 1523/1523 - 2s - loss: 0.4440 - accuracy: 0.8333 - 2s/epoch - 1ms/step
# Epoch 68/100
# 1523/1523 - 2s - loss: 0.4429 - accuracy: 0.8343 - 2s/epoch - 1ms/step
# Epoch 69/100
# 1523/1523 - 2s - loss: 0.4415 - accuracy: 0.8343 - 2s/epoch - 1ms/step
# Epoch 70/100
# 1523/1523 - 2s - loss: 0.4448 - accuracy: 0.8330 - 2s/epoch - 2ms/step
# Epoch 71/100
# 1523/1523 - 2s - loss: 0.4421 - accuracy: 0.8360 - 2s/epoch - 1ms/step
# Epoch 72/100
# 1523/1523 - 2s - loss: 0.4434 - accuracy: 0.8351 - 2s/epoch - 1ms/step
# Epoch 73/100
# 1523/1523 - 2s - loss: 0.4433 - accuracy: 0.8343 - 2s/epoch - 1ms/step
# Epoch 74/100
# 1523/1523 - 2s - loss: 0.4435 - accuracy: 0.8336 - 2s/epoch - 1ms/step
# Epoch 75/100
# 1523/1523 - 2s - loss: 0.4424 - accuracy: 0.8356 - 2s/epoch - 2ms/step
# Epoch 76/100
# 1523/1523 - 2s - loss: 0.4448 - accuracy: 0.8331 - 2s/epoch - 1ms/step
# Epoch 77/100
# 1523/1523 - 2s - loss: 0.4382 - accuracy: 0.8369 - 2s/epoch - 1ms/step
# Epoch 78/100
# 1523/1523 - 2s - loss: 0.4448 - accuracy: 0.8347 - 2s/epoch - 1ms/step
# Epoch 79/100
# 1523/1523 - 2s - loss: 0.4450 - accuracy: 0.8343 - 2s/epoch - 1ms/step
# Epoch 80/100
# 1523/1523 - 2s - loss: 0.4425 - accuracy: 0.8348 - 2s/epoch - 1ms/step
# Epoch 81/100
# 1523/1523 - 2s - loss: 0.4429 - accuracy: 0.8344 - 2s/epoch - 1ms/step
# Epoch 82/100
# 1523/1523 - 2s - loss: 0.4443 - accuracy: 0.8333 - 2s/epoch - 1ms/step
# Epoch 83/100
# 1523/1523 - 2s - loss: 0.4403 - accuracy: 0.8351 - 2s/epoch - 1ms/step
# Epoch 84/100
# 1523/1523 - 2s - loss: 0.4398 - accuracy: 0.8346 - 2s/epoch - 1ms/step
# Epoch 85/100
# 1523/1523 - 2s - loss: 0.4506 - accuracy: 0.8304 - 2s/epoch - 1ms/step
# Epoch 86/100
# 1523/1523 - 2s - loss: 0.4427 - accuracy: 0.8342 - 2s/epoch - 1ms/step
# Epoch 87/100
# 1523/1523 - 2s - loss: 0.4431 - accuracy: 0.8343 - 2s/epoch - 1ms/step
# Epoch 88/100
# 1523/1523 - 2s - loss: 0.4427 - accuracy: 0.8334 - 2s/epoch - 1ms/step
# Epoch 89/100
# 1523/1523 - 2s - loss: 0.4423 - accuracy: 0.8347 - 2s/epoch - 2ms/step
# Epoch 90/100
# 1523/1523 - 2s - loss: 0.4402 - accuracy: 0.8345 - 2s/epoch - 1ms/step
# Epoch 91/100
# 1523/1523 - 2s - loss: 0.4432 - accuracy: 0.8341 - 2s/epoch - 1ms/step
# Epoch 92/100
# 1523/1523 - 2s - loss: 0.4444 - accuracy: 0.8338 - 2s/epoch - 1ms/step
# Epoch 93/100
# 1523/1523 - 2s - loss: 0.4458 - accuracy: 0.8342 - 2s/epoch - 1ms/step
# Epoch 94/100
# 1523/1523 - 2s - loss: 0.4439 - accuracy: 0.8341 - 2s/epoch - 1ms/step
# Epoch 95/100
# 1523/1523 - 2s - loss: 0.4443 - accuracy: 0.8342 - 2s/epoch - 1ms/step
# Epoch 96/100
# 1523/1523 - 2s - loss: 0.4397 - accuracy: 0.8356 - 2s/epoch - 1ms/step
# Epoch 97/100
# 1523/1523 - 2s - loss: 0.4439 - accuracy: 0.8351 - 2s/epoch - 1ms/step
# Epoch 98/100
# 1523/1523 - 2s - loss: 0.4418 - accuracy: 0.8335 - 2s/epoch - 1ms/step
# Epoch 99/100
# 1523/1523 - 2s - loss: 0.4452 - accuracy: 0.8332 - 2s/epoch - 1ms/step
# Epoch 100/100
# 1523/1523 - 2s - loss: 0.4402 - accuracy: 0.8349 - 2s/epoch - 1ms/step

# %%
Y_test_encoded = pd.get_dummies(Y_test)  
Y_test_numpy = Y_test_encoded.values 

resultsd = modeld1.evaluate(X_test, Y_test_numpy, batch_size=10)
print('test acc:', resultsd[1])
# Out:
# 1625/1625 [==============================] - 3s 2ms/step - loss: 0.5141 - accuracy: 0.8439
# test acc: 0.8439327478408813

# %%
prediction = modeld1.predict([[-10, 0.9, 8, 1, 1018]])
predicted_value = prediction
predicted_index = np.argmax(predicted_value)

class_labels = ['Clear', 'Cloudy', 'Foggy']

predicted_class = class_labels[predicted_index]

print(predicted_class)
# Out:
# 1/1 [==============================] - 0s 113ms/step
# Foggy

# %% [markdown]
# ## Model 2

# %%
input_layer = Input(shape=(5,))  
output_shape = Y_train_encoded.shape[1]     
output_layer = Dense(output_shape, activation='sigmoid')(input_layer)
modeld2 = Model(inputs=input_layer, outputs=output_layer)

modeld2.compile(loss=CategoricalCrossentropy(), optimizer='adam', metrics=['accuracy'])

# %%
modeld2.fit(x=X_train, y=Y_train_numpy, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
# 1523/1523 - 2s - loss: 123.3920 - accuracy: 0.5086 - 2s/epoch - 2ms/step
# Epoch 2/100
# 1523/1523 - 2s - loss: 0.8409 - accuracy: 0.7456 - 2s/epoch - 1ms/step
# Epoch 3/100
# 1523/1523 - 2s - loss: 0.4789 - accuracy: 0.8228 - 2s/epoch - 1ms/step
# Epoch 4/100
# 1523/1523 - 2s - loss: 0.4612 - accuracy: 0.8266 - 2s/epoch - 1ms/step
# Epoch 5/100
# 1523/1523 - 2s - loss: 0.4548 - accuracy: 0.8281 - 2s/epoch - 1ms/step
# Epoch 6/100
# 1523/1523 - 2s - loss: 0.4535 - accuracy: 0.8289 - 2s/epoch - 1ms/step
# Epoch 7/100
# 1523/1523 - 2s - loss: 0.4563 - accuracy: 0.8248 - 2s/epoch - 1ms/step
# Epoch 8/100
# 1523/1523 - 2s - loss: 0.4508 - accuracy: 0.8307 - 2s/epoch - 1ms/step
# Epoch 9/100
# 1523/1523 - 2s - loss: 0.4474 - accuracy: 0.8302 - 2s/epoch - 1ms/step
# Epoch 10/100
# 1523/1523 - 2s - loss: 0.4530 - accuracy: 0.8302 - 2s/epoch - 1ms/step
# Epoch 11/100
# 1523/1523 - 2s - loss: 0.4467 - accuracy: 0.8324 - 2s/epoch - 1ms/step
# Epoch 12/100
# 1523/1523 - 2s - loss: 0.4457 - accuracy: 0.8319 - 2s/epoch - 1ms/step
# Epoch 13/100
# 1523/1523 - 2s - loss: 0.4481 - accuracy: 0.8298 - 2s/epoch - 1ms/step
# Epoch 14/100
# 1523/1523 - 2s - loss: 0.4452 - accuracy: 0.8321 - 2s/epoch - 1ms/step
# Epoch 15/100
# 1523/1523 - 2s - loss: 0.4465 - accuracy: 0.8317 - 2s/epoch - 1ms/step
# Epoch 16/100
# 1523/1523 - 2s - loss: 0.4440 - accuracy: 0.8324 - 2s/epoch - 1ms/step
# Epoch 17/100
# 1523/1523 - 2s - loss: 0.4421 - accuracy: 0.8338 - 2s/epoch - 1ms/step
# Epoch 18/100
# 1523/1523 - 2s - loss: 0.4425 - accuracy: 0.8337 - 2s/epoch - 1ms/step
# Epoch 19/100
# 1523/1523 - 2s - loss: 0.4446 - accuracy: 0.8331 - 2s/epoch - 1ms/step
# Epoch 20/100
# 1523/1523 - 2s - loss: 0.4455 - accuracy: 0.8319 - 2s/epoch - 1ms/step
# Epoch 21/100
# 1523/1523 - 2s - loss: 0.4429 - accuracy: 0.8349 - 2s/epoch - 1ms/step
# Epoch 22/100
# 1523/1523 - 2s - loss: 0.4414 - accuracy: 0.8346 - 2s/epoch - 1ms/step
# Epoch 23/100
# 1523/1523 - 2s - loss: 0.4423 - accuracy: 0.8340 - 2s/epoch - 1ms/step
# Epoch 24/100
# 1523/1523 - 2s - loss: 0.4388 - accuracy: 0.8349 - 2s/epoch - 1ms/step
# Epoch 25/100
# 1523/1523 - 2s - loss: 0.4461 - accuracy: 0.8319 - 2s/epoch - 2ms/step
# Epoch 26/100
# 1523/1523 - 2s - loss: 0.4437 - accuracy: 0.8339 - 2s/epoch - 1ms/step
# Epoch 27/100
# 1523/1523 - 2s - loss: 0.4411 - accuracy: 0.8348 - 2s/epoch - 1ms/step
# Epoch 28/100
# 1523/1523 - 2s - loss: 0.4404 - accuracy: 0.8346 - 2s/epoch - 1ms/step
# Epoch 29/100
# 1523/1523 - 2s - loss: 0.4481 - accuracy: 0.8331 - 2s/epoch - 1ms/step
# Epoch 30/100
# 1523/1523 - 2s - loss: 0.4463 - accuracy: 0.8312 - 2s/epoch - 1ms/step
# Epoch 31/100
# 1523/1523 - 2s - loss: 0.4474 - accuracy: 0.8316 - 2s/epoch - 1ms/step
# Epoch 32/100
# 1523/1523 - 2s - loss: 0.4434 - accuracy: 0.8323 - 2s/epoch - 1ms/step
# Epoch 33/100
# 1523/1523 - 2s - loss: 0.4418 - accuracy: 0.8347 - 2s/epoch - 1ms/step
# Epoch 34/100
# 1523/1523 - 2s - loss: 0.4484 - accuracy: 0.8320 - 2s/epoch - 1ms/step
# Epoch 35/100
# 1523/1523 - 2s - loss: 0.4395 - accuracy: 0.8353 - 2s/epoch - 1ms/step
# Epoch 36/100
# 1523/1523 - 2s - loss: 0.4403 - accuracy: 0.8335 - 2s/epoch - 1ms/step
# Epoch 37/100
# 1523/1523 - 2s - loss: 0.4446 - accuracy: 0.8335 - 2s/epoch - 1ms/step
# Epoch 38/100
# 1523/1523 - 2s - loss: 0.4436 - accuracy: 0.8339 - 2s/epoch - 1ms/step
# Epoch 39/100
# 1523/1523 - 2s - loss: 0.4490 - accuracy: 0.8321 - 2s/epoch - 1ms/step
# Epoch 40/100
# 1523/1523 - 2s - loss: 0.4445 - accuracy: 0.8323 - 2s/epoch - 1ms/step
# Epoch 41/100
# 1523/1523 - 2s - loss: 0.4397 - accuracy: 0.8355 - 2s/epoch - 1ms/step
# Epoch 42/100
# 1523/1523 - 2s - loss: 0.4468 - accuracy: 0.8323 - 2s/epoch - 1ms/step
# Epoch 43/100
# 1523/1523 - 2s - loss: 0.4417 - accuracy: 0.8346 - 2s/epoch - 1ms/step
# Epoch 44/100
# 1523/1523 - 2s - loss: 0.4483 - accuracy: 0.8318 - 2s/epoch - 1ms/step
# Epoch 45/100
# 1523/1523 - 2s - loss: 0.4412 - accuracy: 0.8345 - 2s/epoch - 1ms/step
# Epoch 46/100
# 1523/1523 - 2s - loss: 0.4457 - accuracy: 0.8325 - 2s/epoch - 1ms/step
# Epoch 47/100
# 1523/1523 - 2s - loss: 0.4416 - accuracy: 0.8346 - 2s/epoch - 1ms/step
# Epoch 48/100
# 1523/1523 - 2s - loss: 0.4405 - accuracy: 0.8350 - 2s/epoch - 1ms/step
# Epoch 49/100
# 1523/1523 - 2s - loss: 0.4426 - accuracy: 0.8338 - 2s/epoch - 1ms/step
# Epoch 50/100
# 1523/1523 - 2s - loss: 0.4393 - accuracy: 0.8344 - 2s/epoch - 1ms/step
# Epoch 51/100
# 1523/1523 - 2s - loss: 0.4409 - accuracy: 0.8345 - 2s/epoch - 1ms/step
# Epoch 52/100
# 1523/1523 - 2s - loss: 0.4455 - accuracy: 0.8315 - 2s/epoch - 1ms/step
# Epoch 53/100
# 1523/1523 - 2s - loss: 0.4468 - accuracy: 0.8342 - 2s/epoch - 1ms/step
# Epoch 54/100
# 1523/1523 - 2s - loss: 0.4418 - accuracy: 0.8351 - 2s/epoch - 1ms/step
# Epoch 55/100
# 1523/1523 - 2s - loss: 0.4442 - accuracy: 0.8340 - 2s/epoch - 1ms/step
# Epoch 56/100
# 1523/1523 - 2s - loss: 0.4416 - accuracy: 0.8343 - 2s/epoch - 1ms/step
# Epoch 57/100
# 1523/1523 - 2s - loss: 0.4432 - accuracy: 0.8336 - 2s/epoch - 1ms/step
# Epoch 58/100
# 1523/1523 - 2s - loss: 0.4479 - accuracy: 0.8333 - 2s/epoch - 1ms/step
# Epoch 59/100
# 1523/1523 - 2s - loss: 0.4486 - accuracy: 0.8331 - 2s/epoch - 1ms/step
# Epoch 60/100
# 1523/1523 - 2s - loss: 0.4459 - accuracy: 0.8327 - 2s/epoch - 1ms/step
# Epoch 61/100
# 1523/1523 - 2s - loss: 0.4455 - accuracy: 0.8342 - 2s/epoch - 1ms/step
# Epoch 62/100
# 1523/1523 - 2s - loss: 0.4432 - accuracy: 0.8340 - 2s/epoch - 1ms/step
# Epoch 63/100
# 1523/1523 - 2s - loss: 0.4433 - accuracy: 0.8334 - 2s/epoch - 1ms/step
# Epoch 64/100
# 1523/1523 - 2s - loss: 0.4416 - accuracy: 0.8353 - 2s/epoch - 1ms/step
# Epoch 65/100
# 1523/1523 - 2s - loss: 0.4459 - accuracy: 0.8326 - 2s/epoch - 1ms/step
# Epoch 66/100
# 1523/1523 - 2s - loss: 0.4403 - accuracy: 0.8355 - 2s/epoch - 1ms/step
# Epoch 67/100
# 1523/1523 - 2s - loss: 0.4418 - accuracy: 0.8350 - 2s/epoch - 1ms/step
# Epoch 68/100
# 1523/1523 - 2s - loss: 0.4418 - accuracy: 0.8347 - 2s/epoch - 1ms/step
# Epoch 69/100
# 1523/1523 - 2s - loss: 0.4458 - accuracy: 0.8330 - 2s/epoch - 1ms/step
# Epoch 70/100
# 1523/1523 - 2s - loss: 0.4435 - accuracy: 0.8335 - 2s/epoch - 1ms/step
# Epoch 71/100
# 1523/1523 - 2s - loss: 0.4418 - accuracy: 0.8356 - 2s/epoch - 1ms/step
# Epoch 72/100
# 1523/1523 - 2s - loss: 0.4465 - accuracy: 0.8336 - 2s/epoch - 1ms/step
# Epoch 73/100
# 1523/1523 - 2s - loss: 0.4461 - accuracy: 0.8336 - 2s/epoch - 1ms/step
# Epoch 74/100
# 1523/1523 - 2s - loss: 0.4444 - accuracy: 0.8332 - 2s/epoch - 1ms/step
# Epoch 75/100
# 1523/1523 - 2s - loss: 0.4403 - accuracy: 0.8349 - 2s/epoch - 1ms/step
# Epoch 76/100
# 1523/1523 - 2s - loss: 0.4443 - accuracy: 0.8339 - 2s/epoch - 1ms/step
# Epoch 77/100
# 1523/1523 - 2s - loss: 0.4445 - accuracy: 0.8348 - 2s/epoch - 1ms/step
# Epoch 78/100
# 1523/1523 - 2s - loss: 0.4445 - accuracy: 0.8341 - 2s/epoch - 1ms/step
# Epoch 79/100
# 1523/1523 - 2s - loss: 0.4422 - accuracy: 0.8339 - 2s/epoch - 1ms/step
# Epoch 80/100
# 1523/1523 - 2s - loss: 0.4424 - accuracy: 0.8358 - 2s/epoch - 1ms/step
# Epoch 81/100
# 1523/1523 - 2s - loss: 0.4450 - accuracy: 0.8327 - 2s/epoch - 1ms/step
# Epoch 82/100
# 1523/1523 - 2s - loss: 0.4374 - accuracy: 0.8361 - 2s/epoch - 1ms/step
# Epoch 83/100
# 1523/1523 - 2s - loss: 0.4394 - accuracy: 0.8353 - 2s/epoch - 1ms/step
# Epoch 84/100
# 1523/1523 - 2s - loss: 0.4440 - accuracy: 0.8336 - 2s/epoch - 1ms/step
# Epoch 85/100
# 1523/1523 - 2s - loss: 0.4443 - accuracy: 0.8340 - 2s/epoch - 1ms/step
# Epoch 86/100
# 1523/1523 - 2s - loss: 0.4450 - accuracy: 0.8330 - 2s/epoch - 1ms/step
# Epoch 87/100
# 1523/1523 - 2s - loss: 0.4448 - accuracy: 0.8336 - 2s/epoch - 1ms/step
# Epoch 88/100
# 1523/1523 - 2s - loss: 0.4456 - accuracy: 0.8334 - 2s/epoch - 1ms/step
# Epoch 89/100
# 1523/1523 - 2s - loss: 0.4435 - accuracy: 0.8334 - 2s/epoch - 1ms/step
# Epoch 90/100
# 1523/1523 - 2s - loss: 0.4448 - accuracy: 0.8341 - 2s/epoch - 1ms/step
# Epoch 91/100
# 1523/1523 - 2s - loss: 0.4436 - accuracy: 0.8339 - 2s/epoch - 1ms/step
# Epoch 92/100
# 1523/1523 - 2s - loss: 0.4379 - accuracy: 0.8363 - 2s/epoch - 1ms/step
# Epoch 93/100
# 1523/1523 - 2s - loss: 0.4410 - accuracy: 0.8356 - 2s/epoch - 1ms/step
# Epoch 94/100
# 1523/1523 - 2s - loss: 0.4438 - accuracy: 0.8345 - 2s/epoch - 1ms/step
# Epoch 95/100
# 1523/1523 - 2s - loss: 0.4437 - accuracy: 0.8347 - 2s/epoch - 1ms/step
# Epoch 96/100
# 1523/1523 - 2s - loss: 0.4408 - accuracy: 0.8351 - 2s/epoch - 1ms/step
# Epoch 97/100
# 1523/1523 - 2s - loss: 0.4460 - accuracy: 0.8335 - 2s/epoch - 1ms/step
# Epoch 98/100
# 1523/1523 - 2s - loss: 0.4417 - accuracy: 0.8360 - 2s/epoch - 1ms/step
# Epoch 99/100
# 1523/1523 - 2s - loss: 0.4424 - accuracy: 0.8340 - 2s/epoch - 1ms/step
# Epoch 100/100
# 1523/1523 - 2s - loss: 0.4434 - accuracy: 0.8338 - 2s/epoch - 1ms/step

# %%
Y_test_encoded = pd.get_dummies(Y_test)  
Y_test_numpy = Y_test_encoded.values 

resultsd = modeld2.evaluate(X_test, Y_test_numpy, batch_size=10)
print('test acc:', resultsd[1])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11328/4003582860.py in <module>
#       2 Y_test_numpy = Y_test_encoded.values
#       3
# ----> 4 resultsd = modeld2.evaluate(X_test, Y_test_numpy, batch_size=10)
#       5 print('test acc:', resultsd[1])
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in _assert_compile_was_called(self)
#    3683         # (i.e. whether the model is built and its inputs/outputs are set).
#    3684         if not self._is_compiled:
# -> 3685             raise RuntimeError(
#    3686                 "You must compile your model before "
#    3687                 "training/testing. "
#
# RuntimeError: You must compile your model before training/testing. Use `model.compile(optimizer, loss)`.

# %% [markdown]
# ## Model 3

# %%
input_layer = Input(shape=(5,))  
output_shape = Y_train_encoded.shape[1]     
output_layer = Dense(output_shape, activation='softmax')(input_layer)
modeld3 = Model(inputs=input_layer, outputs=output_layer)

modeld3.compile(loss=CategoricalCrossentropy(), optimizer='adam', metrics=['accuracy'])

# %%
modeld3.fit(x=X_train, y=Y_train_numpy, epochs=60, shuffle=True, verbose=2)
# Out:
# Epoch 1/60
# 1523/1523 - 3s - loss: 258.8307 - accuracy: 0.4113 - 3s/epoch - 2ms/step
# Epoch 2/60
# 1523/1523 - 2s - loss: 3.0221 - accuracy: 0.6716 - 2s/epoch - 1ms/step
# Epoch 3/60
# 1523/1523 - 2s - loss: 0.9196 - accuracy: 0.7512 - 2s/epoch - 1ms/step
# Epoch 4/60
# 1523/1523 - 2s - loss: 0.4823 - accuracy: 0.8156 - 2s/epoch - 1ms/step
# Epoch 5/60
# 1523/1523 - 2s - loss: 0.4688 - accuracy: 0.8224 - 2s/epoch - 1ms/step
# Epoch 6/60
# 1523/1523 - 2s - loss: 0.4643 - accuracy: 0.8227 - 2s/epoch - 1ms/step
# Epoch 7/60
# 1523/1523 - 2s - loss: 0.4622 - accuracy: 0.8217 - 2s/epoch - 1ms/step
# Epoch 8/60
# 1523/1523 - 2s - loss: 0.4558 - accuracy: 0.8263 - 2s/epoch - 1ms/step
# Epoch 9/60
# 1523/1523 - 2s - loss: 0.4497 - accuracy: 0.8280 - 2s/epoch - 1ms/step
# Epoch 10/60
# 1523/1523 - 2s - loss: 0.4490 - accuracy: 0.8301 - 2s/epoch - 2ms/step
# Epoch 11/60
# 1523/1523 - 2s - loss: 0.4480 - accuracy: 0.8302 - 2s/epoch - 1ms/step
# Epoch 12/60
# 1523/1523 - 2s - loss: 0.4501 - accuracy: 0.8292 - 2s/epoch - 2ms/step
# Epoch 13/60
# 1523/1523 - 2s - loss: 0.4530 - accuracy: 0.8271 - 2s/epoch - 1ms/step
# Epoch 14/60
# 1523/1523 - 2s - loss: 0.4422 - accuracy: 0.8324 - 2s/epoch - 1ms/step
# Epoch 15/60
# 1523/1523 - 2s - loss: 0.4445 - accuracy: 0.8334 - 2s/epoch - 1ms/step
# Epoch 16/60
# 1523/1523 - 2s - loss: 0.4421 - accuracy: 0.8331 - 2s/epoch - 1ms/step
# Epoch 17/60
# 1523/1523 - 2s - loss: 0.4473 - accuracy: 0.8301 - 2s/epoch - 1ms/step
# Epoch 18/60
# 1523/1523 - 2s - loss: 0.4440 - accuracy: 0.8322 - 2s/epoch - 1ms/step
# Epoch 19/60
# 1523/1523 - 2s - loss: 0.4477 - accuracy: 0.8293 - 2s/epoch - 1ms/step
# Epoch 20/60
# 1523/1523 - 2s - loss: 0.4446 - accuracy: 0.8332 - 2s/epoch - 1ms/step
# Epoch 21/60
# 1523/1523 - 2s - loss: 0.4426 - accuracy: 0.8324 - 2s/epoch - 2ms/step
# Epoch 22/60
# 1523/1523 - 3s - loss: 0.4440 - accuracy: 0.8325 - 3s/epoch - 2ms/step
# Epoch 23/60
# 1523/1523 - 2s - loss: 0.4447 - accuracy: 0.8317 - 2s/epoch - 2ms/step
# Epoch 24/60
# 1523/1523 - 2s - loss: 0.4430 - accuracy: 0.8340 - 2s/epoch - 1ms/step
# Epoch 25/60
# 1523/1523 - 2s - loss: 0.4415 - accuracy: 0.8351 - 2s/epoch - 1ms/step
# Epoch 26/60
# 1523/1523 - 2s - loss: 0.4443 - accuracy: 0.8333 - 2s/epoch - 1ms/step
# Epoch 27/60
# 1523/1523 - 2s - loss: 0.4471 - accuracy: 0.8316 - 2s/epoch - 1ms/step
# Epoch 28/60
# 1523/1523 - 2s - loss: 0.4439 - accuracy: 0.8339 - 2s/epoch - 1ms/step
# Epoch 29/60
# 1523/1523 - 2s - loss: 0.4431 - accuracy: 0.8328 - 2s/epoch - 1ms/step
# Epoch 30/60
# 1523/1523 - 2s - loss: 0.4428 - accuracy: 0.8335 - 2s/epoch - 1ms/step
# Epoch 31/60
# 1523/1523 - 2s - loss: 0.4440 - accuracy: 0.8341 - 2s/epoch - 1ms/step
# Epoch 32/60
# 1523/1523 - 2s - loss: 0.4405 - accuracy: 0.8339 - 2s/epoch - 1ms/step
# Epoch 33/60
# 1523/1523 - 2s - loss: 0.4413 - accuracy: 0.8314 - 2s/epoch - 1ms/step
# Epoch 34/60
# 1523/1523 - 2s - loss: 0.4464 - accuracy: 0.8320 - 2s/epoch - 1ms/step
# Epoch 35/60
# 1523/1523 - 2s - loss: 0.4451 - accuracy: 0.8333 - 2s/epoch - 1ms/step
# Epoch 36/60
# 1523/1523 - 3s - loss: 0.4475 - accuracy: 0.8324 - 3s/epoch - 2ms/step
# Epoch 37/60
# 1523/1523 - 2s - loss: 0.4416 - accuracy: 0.8348 - 2s/epoch - 1ms/step
# Epoch 38/60
# 1523/1523 - 2s - loss: 0.4459 - accuracy: 0.8335 - 2s/epoch - 2ms/step
# Epoch 39/60
# 1523/1523 - 2s - loss: 0.4414 - accuracy: 0.8334 - 2s/epoch - 1ms/step
# Epoch 40/60
# 1523/1523 - 2s - loss: 0.4470 - accuracy: 0.8331 - 2s/epoch - 1ms/step
# Epoch 41/60
# 1523/1523 - 2s - loss: 0.4423 - accuracy: 0.8342 - 2s/epoch - 2ms/step
# Epoch 42/60
# 1523/1523 - 2s - loss: 0.4456 - accuracy: 0.8323 - 2s/epoch - 1ms/step
# Epoch 43/60
# 1523/1523 - 2s - loss: 0.4396 - accuracy: 0.8340 - 2s/epoch - 1ms/step
# Epoch 44/60
# 1523/1523 - 2s - loss: 0.4424 - accuracy: 0.8339 - 2s/epoch - 1ms/step
# Epoch 45/60
# 1523/1523 - 2s - loss: 0.4425 - accuracy: 0.8347 - 2s/epoch - 1ms/step
# Epoch 46/60
# 1523/1523 - 2s - loss: 0.4452 - accuracy: 0.8342 - 2s/epoch - 1ms/step
# Epoch 47/60
# 1523/1523 - 2s - loss: 0.4450 - accuracy: 0.8331 - 2s/epoch - 1ms/step
# Epoch 48/60
# 1523/1523 - 2s - loss: 0.4458 - accuracy: 0.8322 - 2s/epoch - 1ms/step
# Epoch 49/60
# 1523/1523 - 2s - loss: 0.4443 - accuracy: 0.8341 - 2s/epoch - 1ms/step
# Epoch 50/60
# 1523/1523 - 3s - loss: 0.4426 - accuracy: 0.8343 - 3s/epoch - 2ms/step
# Epoch 51/60
# 1523/1523 - 2s - loss: 0.4427 - accuracy: 0.8347 - 2s/epoch - 2ms/step
# Epoch 52/60
# 1523/1523 - 2s - loss: 0.4425 - accuracy: 0.8349 - 2s/epoch - 2ms/step
# Epoch 53/60
# 1523/1523 - 2s - loss: 0.4438 - accuracy: 0.8335 - 2s/epoch - 1ms/step
# Epoch 54/60
# 1523/1523 - 2s - loss: 0.4437 - accuracy: 0.8348 - 2s/epoch - 1ms/step
# Epoch 55/60
# 1523/1523 - 2s - loss: 0.4442 - accuracy: 0.8335 - 2s/epoch - 1ms/step
# Epoch 56/60
# 1523/1523 - 2s - loss: 0.4424 - accuracy: 0.8341 - 2s/epoch - 2ms/step
# Epoch 57/60
# 1523/1523 - 2s - loss: 0.4450 - accuracy: 0.8339 - 2s/epoch - 2ms/step
# Epoch 58/60
# 1523/1523 - 2s - loss: 0.4426 - accuracy: 0.8341 - 2s/epoch - 2ms/step
# Epoch 59/60
# 1523/1523 - 2s - loss: 0.4451 - accuracy: 0.8350 - 2s/epoch - 1ms/step
# Epoch 60/60
# 1523/1523 - 2s - loss: 0.4437 - accuracy: 0.8336 - 2s/epoch - 1ms/step

# %%
Y_test_encoded = pd.get_dummies(Y_test)  
Y_test_numpy = Y_test_encoded.values 

resultsd = modeld3.evaluate(X_test, Y_test_numpy, batch_size=10)
print('test acc:', resultsd[1])
# Out:
# 1625/1625 [==============================] - 3s 2ms/step - loss: 0.4363 - accuracy: 0.8414
# test acc: 0.8414086103439331
